# %% [markdown]
# <a href="https://colab.research.google.com/github/RichardEager0803/Machine-Learning/blob/main/HW1/Analysis_Section.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis Section
#
# Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub?
#
# *   You first need to create a github repository plus a numbered homework subfolder. Then once you have completed your notebook, click File then "save a copy in GitHub". Make sure to specify the correct repo and subfolder for the assignment. Also check the "include a link to colab" option.
#
#
# Did all Module 0 notebooks execute successfully in Colab on the first try, or did you need to adjust any syntax or dependencies?
#
# *   All of my code cells executed on the first try, I did not need to adjust any syntax or any of the dependencies.
#
# Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface).
#
# *   I first created a new public repository with the name "Machine-Learning". I then added a subfolder called "HW1", and included a README.md file. I then committed my completed notebooks from google colab to the github repository in the HW1 subfolder.
#
# Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms?
#
# *   Becoming proficient in the Python syntax and data structures creates a strong foundation essential for Machine Learning. If you are weak on these fundamentals, you could end up spending more time debugging basic errors rather than learning the Machine Learning algorithms themselves.
